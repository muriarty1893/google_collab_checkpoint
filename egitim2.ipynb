# %% [markdown]
# <a href="https://colab.research.google.com/github/muriarty1893/google_collab_checkpoint/blob/main/egitim2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('occ.csv')

# %%
df.head()
# Out:
#    age gender  occupation zip_code
# 0   24      M  technician    85711
# 1   53      F       other    94043
# 2   23      M      writer    32067
# 3   24      M  technician    43537
# 4   33      F       other    15213

# %%
df.tail(10)
# Out:
#      age gender     occupation zip_code
# 933   61      M       engineer    22902
# 934   42      M         doctor    66221
# 935   24      M          other    32789
# 936   48      M       educator    98072
# 937   38      F     technician    55038
# 938   26      F        student    33319
# 939   32      M  administrator    02215
# 940   20      M        student    97229
# 941   48      F      librarian    78209
# 942   22      M        student    77841

# %%
df.shape
# Out:
# (943, 4)

# %%
print("datamızda ", df.shape[0], "adet observation, data point  var")
# Out:
# datamızda  943 adet observation, data point  var

# %%
print("datamızda ", df.shape[1], "adet değişken var")
# Out:
# datamızda  4 adet değişken var

# %%
list(df.columns)[0:]
# Out:
# ['age', 'gender', 'occupation', 'zip_code']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=943, step=1)

# %%
df.loc[0] #isimlerine göre
# Out:
# age                   24
# gender                 M
# occupation    technician
# zip_code           85711
# Name: 0, dtype: object

# %%
df.loc[:,'age'] #satır ve stüna ulaşmak için ! satuır ve stün isimi ile
# Out:
# 0      24
# 1      53
# 2      23
# 3      24
# 4      33
#        ..
# 938    26
# 939    32
# 940    20
# 941    48
# 942    22
# Name: age, Length: 943, dtype: int64

# %%
df['age']
# Out:
# 0      24
# 1      53
# 2      23
# 3      24
# 4      33
#        ..
# 938    26
# 939    32
# 940    20
# 941    48
# 942    22
# Name: age, Length: 943, dtype: int64

# %%
df.iloc[:,0] #satır ve stün numaralaı için
# Out:
# 0      24
# 1      53
# 2      23
# 3      24
# 4      33
#        ..
# 938    26
# 939    32
# 940    20
# 941    48
# 942    22
# Name: age, Length: 943, dtype: int64

# %%
df2=df #ikiside aynı dosyayı gösteren iki isim, yeni kopya oluşturmaz

# %%
df2=df.copy() #bu oluşturur

# %%
df2.drop(1,axis=0) #1 i satrılar arasında ara ve bulunca sil, aslında silmez sadece nasıl görüneceğini yazar
# Out:
#      age gender     occupation zip_code
# 0     24      M     technician    85711
# 2     23      M         writer    32067
# 3     24      M     technician    43537
# 4     33      F          other    15213
# 5     42      M      executive    98101
# ..   ...    ...            ...      ...
# 938   26      F        student    33319
# 939   32      M  administrator    02215
# 940   20      M        student    97229
# 941   48      F      librarian    78209
# 942   22      M        student    77841
#
# [942 rows x 4 columns]

# %%
df2.drop(1,axis=0, inplace=True) # şimdi siler

# %%
df2.iloc[1] #sırayı ifade eder isimi değil
# Out:
# age               23
# gender             M
# occupation    writer
# zip_code       32067
# Name: 2, dtype: object

# %%
df.dtypes # data çeşitleri
# Out:
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
date: '22/09/2024' string # string den date time a geçmek için
datetime -->

# %%
df[['occupation']]
# Out:
#         occupation
# 0       technician
# 1            other
# 2           writer
# 3       technician
# 4            other
# ..             ...
# 938        student
# 939  administrator
# 940        student
# 941      librarian
# 942        student
#
# [943 rows x 1 columns]

# %%
c=list(df.columns) # isimleri listeye çevir
c
# Out:
# ['age', 'gender', 'occupation', 'zip_code']

# %%
c.index('occupation') # isimin yerini bulma, iloc ta kullanmak için.
# Out:
# 2

# %%
# how many occupatipon in dataset ?
df['occupation'].value_counts()
# şuan cevap değil
# Out:
# occupation
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# homemaker          7
# doctor             7
# Name: count, dtype: int64

# %%
len(df['occupation'].value_counts().index) # occupation isimi sayısı, sadece birer tane değil !
# Out:
# 21

# %%
len(df['occupation'].unique()) # şimdi birere tane - doğru cevap
# Out:
# 21

# %%
df['occupation'].nunique() #üsttekiyle aynı
# Out:
# 21

# %%
# most frequent occupation ? en fazla sayıda occupation ?
#value_counts() en fazla olanda en aza sıralar yani birinci en fazla olandır
print(df['occupation'].value_counts().index[0]) # adı
print(df['occupation'].value_counts().values[0]) # sayısı
# Out:
# student
# 196

# %%
df.describe(include='all') # include demezisen sadece 1. yi alıyor, freq meaning: top daki değerlerin sayısı
# Out:
#                age gender occupation zip_code
# count   943.000000    943        943      943
# unique         NaN      2         21      795
# top            NaN      M    student    55414
# freq           NaN    670        196        9
# mean     34.051962    NaN        NaN      NaN
# std      12.192740    NaN        NaN      NaN
# min       7.000000    NaN        NaN      NaN
# 25%      25.000000    NaN        NaN      NaN
# 50%      31.000000    NaN        NaN      NaN
# 75%      43.000000    NaN        NaN      NaN
# max      73.000000    NaN        NaN      NaN

# %%
df['age'].mean()
# mean of age of users
# Out:
# 34.05196182396607

# %%
#what is the age with least occurance ?
df['age'].value_counts().tail(10) # 1 olan kaç kişi var ?
# Out:
# age
# 63    3
# 69    2
# 62    2
# 64    2
# 68    2
# 7     1
# 11    1
# 66    1
# 10    1
# 73    1
# Name: count, dtype: int64

# %%
minfreq = df['age'].value_counts().values[-1] # en az 1 kişi var en yaşlı olan

# %%
df['age'].value_counts().values # hangileri bir ? hangilerinin bir olduğunun konumlarını bulabilirsem bu konumlara
#karşılık gelen yaşlarda en az bununan yaşlar olacak
# Out:
# array([39, 38, 37, 36, 35, 34, 33, 32, 32, 28, 28, 27, 27, 26, 25, 23, 23,
#        22, 21, 21, 21, 20, 20, 20, 19, 19, 18, 17, 17, 15, 14, 14, 13, 12,
#        12, 11, 10,  9,  9,  6,  6,  6,  5,  5,  4,  3,  3,  3,  3,  3,  3,
#         3,  2,  2,  2,  2,  1,  1,  1,  1,  1])

# %%
df['age'].value_counts().index
# Out:
# Index([30, 25, 22, 28, 27, 26, 24, 20, 29, 23, 32, 21, 35, 33, 31, 44, 19, 39,
#        36, 42, 40, 50, 51, 48, 49, 37, 18, 34, 38, 45, 47, 17, 43, 46, 53, 55,
#        41, 60, 57, 56, 15, 52, 16, 13, 54, 65, 61, 59, 14, 58, 70, 63, 69, 62,
#        64, 68,  7, 11, 66, 10, 73],
#       dtype='int64', name='age')

# %%
list(df['age'].value_counts().values).index(1)
# Out:
# 56

# %%
loc_1 = df['age'].value_counts().values==1 #hangileri 1 e eşşit ?
loc_1
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True,  True,  True,  True,  True])

# %%
df['age'].value_counts().index[loc_1] # loc 1 in true olduğu yerler, aradığımız konumları ifade etmek için kullanıldı
# Out:
# Index([7, 11, 66, 10, 73], dtype='int64', name='age')
